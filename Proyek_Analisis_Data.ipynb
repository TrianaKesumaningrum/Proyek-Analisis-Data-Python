# %% [markdown]
# # PROYEK ANALISIS DATA

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# 1. Bagaimana persebaran penggunaan sepeda berdasarkan hari libur dan hari biasa jika dilihat dari rata-rata penggunaan sepeda?
# 2. Berdasarkan rata-rata penggunaan sepeda yang dilihat dari kondisi cuaca, cuaca manakah yang memiliki banyak peminat penggunaan sepeda?
# 3. Berdasarkan rata-rata penggunaan sepeda yang dilihat dari kondisi musim, musim manakah yang memiliki banyak peminat penggunaan sepeda?
# 4. Berapa banyak pengguna sepeda yang terdaftar dan tidak terdaftar?

# %% [markdown]
# ## Menyiapkan Library

# %%
import numpy as np # Mengimport library numpy yang digunakan untuk manipulasi data numerik
import pandas as pd # Mengimport library pandas yang digunakan untuk memanipulasi dan menganalisis data
import matplotlib.pyplot as plt # Mengimport library matplotlib yang digunakan untuk visualisasi data
import seaborn as sns # Mengimport library matplotlib yang digunakan untuk visualisasi data atraktif dan informatif

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
# Menggunakan metode read_csv dari pandas untuk membaca file CSV dari URL yang diberikan dan menyimpannya dalam dataframe hour_df
day_df = pd.read_csv("https://raw.githubusercontent.com/TrianaKesumaningrum/Proyek-Analisis-Data-Python/master/data/day.csv")
# Menampilkan lima baris pertama dari DataFrame hour_df
day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
# Menggunakan metode read_csv dari pandas untuk membaca file CSV dari URL yang diberikan dan menyimpannya dalam dataframe hour_df
hour_df = pd.read_csv("https://raw.githubusercontent.com/TrianaKesumaningrum/Proyek-Analisis-Data-Python/master/data/hour.csv")
# Menampilkan lima baris pertama dari DataFrame hour_df
hour_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# Menilai Tabel Day

# %%
# Memanggil fungsi info() pada DataFrame day_df untuk memberikan informasi ringkas tentang struktur DataFrame
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
# Menghitung jumlah nilai NaN pada setiap kolom dataframe
day_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
# Menghitung jumlah total duplikat dalam dataframe
print("Jumlah Duplikasi: ", day_df.duplicated().sum())
# Out:
# Jumlah Duplikasi:  0

# %%
# describe() digunakan untuk memberikan ringkasan statistik deskriptif untuk kolom-kolom numerik dalam DataFrame
day_df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %% [markdown]
# Menilai Tabel hour

# %%
# Memanggil fungsi info() pada DataFrame hour_df untuk memberikan informasi ringkas tentang struktur DataFrame
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
# Menghitung jumlah nilai NaN pada setiap kolom dataframe
hour_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
# Menghitung jumlah total duplikat dalam dataframe
print("Jumlah Duplikasi: ", hour_df.duplicated().sum())
# Out:
# Jumlah Duplikasi:  0

# %%
# describe() digunakan untuk memberikan ringkasan statistik deskriptif untuk kolom-kolom numerik dalam DataFrame
hour_df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# Membersihkan data pada dataframe day

# %%
# Mengganti tipe data yang salah pada dataframe day
datetime_columns = ["dteday"]

for column in datetime_columns:
  day_df[column] = pd.to_datetime(day_df[column])

day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(11)
# memory usage: 91.5 KB

# %% [markdown]
# Membersihkan data pada dataframe hour

# %%
# Mengganti tipe data yang salah pada dataframe hour
datetime_columns = ["dteday"]

for column in datetime_columns:
  hour_df[column] = pd.to_datetime(hour_df[column])

hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  datetime64[ns]
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(12)
# memory usage: 2.3 MB

# %% [markdown]
# ## Exploring Data Analysis (EDA)

# %%
# Menggunakan metode describe() dengan argumen include='all', untuk memberikan ringkasan statistik deskriptif untuk semua kolom
day_df.describe(include='all')
# Out:
# <ipython-input-205-353bded60b04>:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   day_df.describe(include='all')
#            instant               dteday      season          yr        mnth  \
# count   731.000000                  731  731.000000  731.000000  731.000000
# unique         NaN                  731         NaN         NaN         NaN
# top            NaN  2011-01-01 00:00:00         NaN         NaN         NaN
# freq           NaN                    1         NaN         NaN         NaN
# first          NaN  2011-01-01 00:00:00         NaN         NaN         NaN
# last           NaN  2012-12-31 00:00:00         NaN         NaN         NaN
# mean    366.000000                  NaN    2.496580    0.500684    6.519836
# ...

# %%
# Menggunakan metode describe() dengan argumen include='all', untuk memberikan ringkasan statistik deskriptif untuk semua kolom
hour_df.describe(include="all")
# Out:
# <ipython-input-206-2d3781e907f6>:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   hour_df.describe(include="all")
#            instant               dteday        season            yr  \
# count   17379.0000                17379  17379.000000  17379.000000
# unique         NaN                  731           NaN           NaN
# top            NaN  2011-01-01 00:00:00           NaN           NaN
# freq           NaN                   24           NaN           NaN
# first          NaN  2011-01-01 00:00:00           NaN           NaN
# last           NaN  2012-12-31 00:00:00           NaN           NaN
# mean     8690.0000                  NaN      2.501640      0.502561
# std      5017.0295                  NaN      1.106918      0.500008
# ...

# %%
# Melakukan penggabungan antara DataFrame day_df dan hour_df berdasarkan kolom 'dteday'
bikesharing_df = day_df.merge(hour_df, on='dteday', how='inner', suffixes=('_day', '_hour'))
bikesharing_df.sample(10)
# Out:
#        instant_day     dteday  season_day  yr_day  mnth_day  holiday_day  \
# 15980          673 2012-11-03           4       1        11            0
# 12114          510 2012-05-24           2       1         5            0
# 12651          533 2012-06-16           2       1         6            0
# 12261          517 2012-05-31           2       1         5            0
# 3122           135 2011-05-15           2       0         5            0
# 15206          639 2012-09-30           4       1         9            0
# 13226          557 2012-07-10           3       1         7            0
# 7742           328 2011-11-24           4       0        11            1
# 15146          637 2012-09-28           4       1         9            0
# 9297           393 2012-01-28           1       1         1            0
#
#        weekday_day  workingday_day  weathersit_day  temp_day  ...  \
# 15980            6               0               2  0.343333  ...
# ...

# %%
# Membuat kamus weathersit_labels untuk memetakan kode cuaca (dalam kolom 'weathersit_day') ke label cuaca yang sesuai.
# Menggunakan metode .map()
weathersit_labels = {
    1: 'Cerah',
    2: 'Berawan',
    3: 'Hujan',
}
bikesharing_df['weathersit_label'] = bikesharing_df['weathersit_day'].map(weathersit_labels)

# %%
# Melakukan pengelompokkan berdasarkan label cuaca yang telah dibuat sebelumnya ('weathersit_label')
# Kemudian menghitung rata-rata nilai 'cnt_day' (jumlah sepeda yang disewa) untuk setiap label cuaca.
bikesharing_df.groupby('weathersit_label')['cnt_day'].mean().reset_index().sort_values("cnt_day")
# Out:
#   weathersit_label      cnt_day
# 2            Hujan  1914.700855
# 0          Berawan  4062.717595
# 1            Cerah  4895.177083

# %%
# Membuat kamus weathersit_labels untuk memetakan kode cuaca (dalam kolom 'weathersit_day') ke label cuaca yang sesuai.
# Menggunakan metode .map()
season_labels = {
    1: 'Dingin',
    2: 'Semi',
    3: 'Panas',
    4: 'Gugur',
}
bikesharing_df['season_label'] = bikesharing_df['season_day'].map(season_labels)

# %%
# Melakukan pengelompokkan berdasarkan label season yang telah dibuat sebelumnya ('weathersit_label')
# Kemudian menghitung rata-rata nilai 'cnt_day' (jumlah sepeda yang disewa) untuk setiap label season.
bikesharing_df.groupby('season_label')['cnt_day'].mean().reset_index().sort_values("cnt_day")
# Out:
#   season_label      cnt_day
# 0       Dingin  2635.348185
# 1        Gugur  4765.366021
# 3         Semi  4995.253119
# 2        Panas  5654.093194

# %%
# Pengelompokkan berdasarkan hari kerja ('weekend_day')
# kemudian menghitung rata-rata nilai 'cnt_day' (jumlah sepeda yang disewa)
bikesharing_df.groupby('holiday_day')['cnt_day'].mean().reset_index().sort_values("cnt_day")
# Out:
#    holiday_day      cnt_day
# 1            1  3750.060000
# 0            0  4556.906215

# %%
# Membuat kamus weekday_labels untuk memetakan kode hari dalam seminggu ke label hari yang sesuai.
# Menggunakan metode .map()
weekday_labels = {
    1: 'Senin',
    2: 'Selasa',
    3: 'Rabu',
    4: 'Kamis',
    5: 'Jumat',
    6: 'Sabtu',
    7: 'Minggu'
}
bikesharing_df['weekday_label'] = bikesharing_df['weekday_day'].map(weekday_labels)

# %%
# Melakukan pengelompokkan berdasarkan label hari yang telah dibuat sebelumnya ('weekday_label')
# Kemudian menghitung rata-rata nilai 'cnt_day' (jumlah sepeda yang disewa) untuk setiap label hari.
bikesharing_df.groupby('weekday_label')['cnt_day'].mean().reset_index()
# Out:
#   weekday_label      cnt_day
# 0         Jumat  4700.838359
# 1         Kamis  4703.503440
# 2          Rabu  4574.609293
# 3         Sabtu  4561.544188
# 4        Selasa  4566.708113
# 5         Senin  4391.920936

# %%
# Menghitung total jumlah sepeda yang disewa (terdaftar dan tidak terdaftar)
# dengan menjumlahkan nilai dalam kolom 'registered_day' dan 'casual_day'
total_terdaftar = bikesharing_df['registered_day'].sum()
total_tidakTerdaftar = bikesharing_df['casual_day'].sum()

# Menampilkan hasil perhitungan
print("Total sewa sepeda (terdaftar):", total_terdaftar)
print("Total sewa sepeda (tidak terdaftar):", total_tidakTerdaftar)
# Out:
# Total sewa sepeda (terdaftar): 63943480
# Total sewa sepeda (tidak terdaftar): 14847570

# %% [markdown]
# ##Visualisasi Data

# %%
# Menghitung rata-rata penyewaan sepeda berdasarkan hari libur
avg_holiday = bikesharing_df.groupby('holiday_day')['cnt_day'].mean()
# Menghitung rata-rata penyewaan sepeda berdasarkan hari dalam seminggu
avg_weekday = bikesharing_df.groupby('weekday_day')['cnt_day'].mean()

# Label untuk pie chart pada hari libur
labels_holiday = ['Hari Libur', 'Hari Tidak Libur']
# Label untuk pie chart pada hari dalam seminggu
labels_weekday = ['Senin', 'Selasa', 'Rabu', 'Kamis', 'Jumat', 'Sabtu', 'Minggu']

# Plot
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Pie chart untuk rata-rata pada hari libur
axes[0].pie(avg_holiday, labels=labels_holiday, autopct='%1.1f%%', colors=('#ff8fab', '#ffc2d1'))
axes[0].set_title('Rata-rata Penyewaan Sepeda pada Hari Libur')

# Pie chart untuk rata-rata pada setiap hari
axes[1].pie(avg_weekday, labels=labels_weekday, autopct='%1.1f%%', colors=('#ddb892', '#b08968', '#7f5539', '#9c6644'))
axes[1].set_title('Rata-rata Penyewaan Sepeda pada Hari dalam Seminggu')

# Menampilkan plot
plt.show()

# %%
# Melakukan pengelompokan berdasarkan label cuaca dan menghitung rata-rata jumlah pengguna sepeda
avg_weather = bikesharing_df.groupby('weathersit_label')['cnt_day'].mean().reset_index()

# Mengatur ukuran gambar plot
plt.figure(figsize=(10, 7))

# Membuat diagram batang
plt.bar(avg_weather['weathersit_label'], avg_weather['cnt_day'], color='#ff8fab')

# Menambahkan judul dan label sumbu
plt.title('Rata-rata Jumlah Pengguna Sepeda berdasarkan Kondisi Cuaca')
plt.xlabel('Kondisi Cuaca')
plt.ylabel('Rata-rata Jumlah Pengguna Sepeda')

# Memutar label sumbu x sebesar 45 derajat
plt.xticks(rotation=45)

# Menambahkan grid pada sumbu y
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Menampilkan plot
plt.show()

# %%
# Melakukan pengelompokan berdasarkan label season dan menghitung rata-rata jumlah pengguna sepeda
avg_season = bikesharing_df.groupby('season_label')['cnt_day'].mean().reset_index()

# Mengatur ukuran gambar plot
plt.figure(figsize=(10, 7))

# Membuat diagram batang
plt.bar(avg_season['season_label'], avg_season['cnt_day'], color='#ff8fab')

# Menambahkan judul dan label sumbu
plt.title('Rata-rata Jumlah Pengguna Sepeda berdasarkan Kondisi Musim')
plt.xlabel('Kondisi Musim')
plt.ylabel('Rata-rata Jumlah Pengguna Sepeda')

# Memutar label sumbu x sebesar 45 derajat
plt.xticks(rotation=45)

# Menambahkan grid pada sumbu y
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Menampilkan plot
plt.show()

# %%
# Menghitung jumlah total sewa sepeda terdaftar dan tidak terdaftar
cnt_bikesharing = [bikesharing_df['registered_day'].sum(), bikesharing_df['casual_day'].sum()]

# Labels untuk plot
labels = ['Terdaftar', 'Tidak Terdaftar']

# Plot bar horizontal
plt.figure(figsize=(8, 6))
plt.barh(labels, cnt_bikesharing, color=['#ff8fab', '#ffccd5'])

# Judul dan label sumbu
plt.title('Total Sewa Sepeda (Terdaftar dan Tidak Terdaftar)')
plt.xlabel('Jumlah')
plt.ylabel('Tipe Sewa Sepeda')

# Tampilkan plot
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# **Pertanyaan 1**

# %% [markdown]
# Penggunaan sepeda pada hari libur cenderung lebih tinggi dibandingkan dengan hari tidak libur, karena kebanyakan orang memanfaatkan waktunya untuk liburan salah satunya dengan bersepeda. Namun, pada setiap hari dalam seminggu, penggunaan sepeda cenderung lebih tinggi pada hari Jumat dan Sabtu, dengan rata-rata penggunaan sepeda mencapai 14,8%.

# %% [markdown]
# **Pertanyaan 2**

# %% [markdown]
# Berdasarkan visualisasi data yang menampilkan rata-rata jumlah pengguna sepeda berdasarkan kondisi cuaca, terlihat bahwa pengguna sepeda tertinggi terjadi pada kondisi cuaca cerah. Hal ini dapat diinterpretasikan bahwa cuaca yang cerah cenderung memberikan kondisi yang lebih baik bagi orang untuk bersepeda, dibandingkan dengan cuaca yang buruk atau tidak mendukung seperti hujan atau salju.

# %% [markdown]
# **Pertanyaann 3**

# %% [markdown]
# Berdasarkan visualisasi data yang menampilkan rata-rata jumlah pengguna sepeda berdasarkan kondisi musim, terlihat bahwa pengguna sepeda tertinggi terjadi pada kondisi musim panas. Hal ini dapat diinterpretasikan bahwa musim panas cenderung memberikan kondisi yang lebih baik bagi orang untuk bersepeda, dibandingkan dengan musim yang buruk atau tidak mendukung seperti musim dingin.

# %% [markdown]
# **Pertanyaan 4**

# %% [markdown]
# Berdasarkan perhitungan dan visualisasi data yang telah dilakukan, dapat diketahui bahwa pengguna yang terdaftar terdapat sebanyak 63943480 dan jumlah pengguna sepeda yang tidak terdaftar sebanyak 14847570.
